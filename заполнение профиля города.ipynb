# %% [markdown]
# ## Подсчет профиля города

# %% [markdown]
# ### Содержание:
# * Подгрузка выборки
# * Подсчет количества по годам
# * Подсчет лидеров заявителей города
# * [Подсчет количества по областям с fractional count](#second-bullet)
# * Подсчет заявителей по областям с $ИТС \geq 1$

# %%
import pandas as pd
from glob import glob
from collections import defaultdict
import numpy as np

# %% [markdown]
# Подгрузим загруженную с patstat выборку

# %%
CITY_NAME = 'роли'

# %%
df = pd.DataFrame([])
for indx, path in enumerate((glob('{}\\resulttable-*\\*'.format(CITY_NAME)))):
    print(f'Количество заявок в архиве #{indx}:', pd.read_table(path, sep=';')['appln_id'].nunique())
    df = pd.concat([df, pd.read_table(path, sep=';')])
# Out:
# Количество заявок в архиве #0: 5224
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead.
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#     appln_id  appln_filing_year appln_auth  techn_field_nr  person_id  \
# 0  416789673               2014         EP               1      20775
# 1  416789673               2014         EP               3      20775
# 2  419279440               2014         EP               8      20775
# 3  422592775               2014         EP               8      20775
# 4  425994131               2014         EP               8      20775
#
#   person_ctry_code person_name                       person_address
# 0               US  CREE, INC.  4600 Silicon Drive,Durham, NC 27703
# 1               US  CREE, INC.  4600 Silicon Drive,Durham, NC 27703
# 2               US  CREE, INC.  4600 Silicon Drive,Durham, NC 27703
# 3               US  CREE, INC.  4600 Silicon Drive,Durham, NC 27703
# 4               US  CREE, INC.  4600 Silicon Drive,Durham, NC 27703

# %% [markdown]
# **Посчитаем количество заявок города по годам**

# %%
pd.DataFrame(df.groupby('appln_filing_year').nunique()['appln_id']).T
# Out:
# appln_filing_year  2014  2015  2016  2017
# appln_id           1568  1330  1441   885

# %% [markdown]
# **Посчитаем топ заявителей по городу**
# * Нужно оставить тех, кто входит в первые 2 квартиля

# %%
# %%time
current_aplicant = []
for indx, person_name in enumerate(df.person_name.unique()):
    #df[df.person_name == person_name].groupby(['appln_filing_year', 'appln_id']).nunique()['appln_id'].groupby('appln_filing_year').size()
    aux_ = pd.DataFrame(df[df.person_name == person_name].groupby(['appln_filing_year', 'appln_id']).nunique()['appln_id'].groupby('appln_filing_year').size()).T
    #aux_.index = [person_name]
    #aux_ = pd.DataFrame(dict(aux_)).reset_index()
    current_aplicant.append([])
    current_aplicant[indx].append(person_name)
    for year in [2014, 2015, 2016, 2017]:
        try:
            current_aplicant[indx].append(aux_[year][0])
        except KeyError:
            current_aplicant[indx].append(0)
# Out:
# Wall time: 3.06 s

# %%
df_applicants_leaders = pd.DataFrame(current_aplicant, columns=['person_name', 2014, 2015, 2016, 2017]).assign(summa2014to16 = lambda x:x[2014]+x[2015]+x[2016])
df_applicants_leaders.columns = df_applicants_leaders.columns.tolist()[0:-1] + ['2014-16']

# %%
quantiles = df_applicants_leaders['2014-16'].quantile([0.25,0.5,0.75])
quantiles
# Out:
# 0.25    1.0
# 0.50    1.0
# 0.75    3.0
# Name: 2014-16, dtype: float64

# %%
df_to_save = df_applicants_leaders[df_applicants_leaders['2014-16'] >= quantiles[0.5]].sort_values('2014-16', \
                                                    ascending=False)
df_to_save.to_excel(f'{CITY_NAME}\\{CITY_NAME}_лидеры.xlsx', index=False)

# %%
df[['appln_id', 'appln_filing_year']].nunique()
# Out:
# appln_id             5224
# appln_filing_year       4
# dtype: int64

# %% [markdown]
# **Посчитаем значения по областям с учетом fractional_count** <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# > **структура словаря**:
# > ```
# >    Область
# >        Год i
# >            Число заявок за год i с учетом fractional_count
# >
# >Пример
# >    Область
# >        2014
# >            Число заявок за год i с учетом fractional_count
# >        2015
# >            Число заявок за год i с учетом fractional_count
# >        2016
# >            Число заявок за год i с учетом fractional_count
# >        2017
# >            Число заявок за год i с учетом fractional_count
# >```

# %%
'''
    На вход:
        сырая табличка заявок
    На выход: словарь структуры выше, содержащий в себе количество заявок по областям по годам 
            с учетом fractional count
    
    dict_of_tech_fileds_per_city :dict: словарь для счёта по тех.областям
    tech_fileds_column :pd Series: колонка для хранения тех.областей
    appln_year :np array: (фактически: единичной длины) 
    tech_fileds_list :np array: лист со всеми (уникальными) тех.бластями заявки, 
                                длина листа равна количеству областей у заявки 
    fractional_count_per_application :float: число с плавающей точкой, равное доле, 
    которую нужно прибавить к каждой области по итогами анализа текущей заявки
    1/количество тех.областей = dfrac{1}{len(tech_fileds_list)}
'''

# создадим словарь структуры, описанной выше
dict_of_tech_fileds_per_city = defaultdict(lambda: defaultdict(np.float16))

# пройдёмся по всем уникальным заявкам в цикле и возьмём
#    А) Колонку с тех областями для каждой заявки
#    Б) Год каждой заявки
for appln_id in df['appln_id'].unique():
    tech_fileds_column = df[df['appln_id'] == appln_id].techn_field_nr
    appln_year = df[df['appln_id'] == appln_id].appln_filing_year.unique()
    # если внезапно было больше одного года для заявки, залогируем это выводом года. пока такого не было
    if len(appln_year) != 1:       
        print(appln_year)
    tech_fileds_list = tech_fileds_column.unique()
    fractional_count_per_application = 1 / len(tech_fileds_list)
    
    # добавим в словарь к каждой встретившеся в заявке области долю fractional_count по итогам анализа заявки
    for tech_filed in tech_fileds_list:
        dict_of_tech_fileds_per_city[tech_filed][appln_year[0]] += fractional_count_per_application

# %%
df_techs = pd.DataFrame(dict_of_tech_fileds_per_city).T.sort_index().replace(np.nan, 0)
df_techs = df_techs.assign(summa2014to16 = lambda x:x[2014]+x[2015]+x[2016])
df_techs.columns = df_techs.columns.tolist()[0:-1] + ['2014-16']
df_techs.head()
# Out:
#          2014        2015        2016       2017     2014-16
# 1  160.683333   91.333333   71.333333  65.633333  323.350000
# 2   22.916667   21.476190   17.033333  11.116667   61.426190
# 3   30.333333   22.333333   22.033333  19.983333   74.700000
# 4  122.533333  113.916667  126.866667  84.250000  363.316667
# 5    7.333333    3.500000    4.000000   5.416667   14.833333

# %%
df_techs
# Out:
#           2014        2015        2016        2017     2014-16
# 1   160.683333   91.333333   71.333333   65.633333  323.350000
# 2    22.916667   21.476190   17.033333   11.116667   61.426190
# 3    30.333333   22.333333   22.033333   19.983333   74.700000
# 4   122.533333  113.916667  126.866667   84.250000  363.316667
# 5     7.333333    3.500000    4.000000    5.416667   14.833333
# 6   248.166667  265.892857  260.366667  206.150000  774.426190
# 7    47.616667   27.333333   27.033333   16.550000  101.983333
# 8   111.333333   50.833333   35.250000   44.083333  197.416667
# 9    19.033333   10.283333    7.033333   11.041667   36.350000
# 10   51.466667   45.650000   55.033333   34.283333  152.150000
# 11   27.683333   22.033333   33.516667   10.283333   83.233333
# 12   30.200000   19.426190   23.083333   20.633333   72.709524
# 13  123.241667  105.061111  149.283333   72.691667  377.586111
# 14   62.816667   62.500000   60.650000   28.616667  185.966667
# 15  110.316667  101.750000  132.816667   47.783333  344.883333
# 16  156.825000  166.611111  159.200000   89.575000  482.636111
# 17   11.166667    5.727778   12.083333    2.916667   28.977778
# 18    7.958333   10.611111    7.000000    7.991667   25.569444
# 19   28.333333   20.116667   34.666667   13.283333   83.116667
# 20    2.500000    6.483333    6.916667    2.500000   15.900000
# 21   11.983333    8.542857    8.083333    3.500000   28.609524
# 22    3.458333    2.944444    3.616667    1.666667   10.019444
# 23   18.808333   27.520635   25.233333   12.908333   71.562302
# 24    8.041667    8.627778    7.783333    3.208333   24.452778
# 25    8.616667   11.592857    7.750000    4.333333   27.959524
# 26    4.833333    5.416667    6.000000    0.666667   16.250000
# 27   14.208333    7.177778    9.416667   10.375000   30.802778
# 28    4.566667    6.376190    8.166667    4.166667   19.109524
# 29   16.941667    9.977778   20.283333   11.275000   47.202778
# 30    8.750000   13.600000    8.616667    6.666667   30.966667
# 31   21.750000   10.900000   25.500000    2.166667   58.150000
# 32   20.666667    7.533333   14.400000   10.383333   42.600000
# 33   10.333333    5.916667   14.366667    4.366667   30.616667
# 34    8.250000   16.250000   19.916667    6.950000   44.416667
# 35   24.333333   14.750000   16.666667    7.583333   55.750000

# %% [markdown]
# Получим заявителей по областям с $ИТС >= 1.1$
# * Нужно убрать хвосты, равные _менее_ $5$ заявок за $2014-2016$ годы

# %%
fields_with_its_greater_or_equal1and1 = '''1
4
6
8
10
12
13
15
16
23'''
fields_with_its_greater_or_equal1and1 = fields_with_its_greater_or_equal1and1.split('\n')
print('string of fileds for sql: (', ', '.join(fields_with_its_greater_or_equal1and1), ')')
fields_with_its_greater_or_equal1and1 = tuple(map(int, fields_with_its_greater_or_equal1and1))
# Out:
# string of fileds for sql: ( 1, 4, 6, 8, 10, 12, 13, 15, 16, 23 )

# %%
# создадим словарь структуры, описанной выше
dict_of_leaders_per_tech_fileds = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))

for appln_id in df['appln_id'].unique():
    
    current_app = df[df['appln_id'] == appln_id][['appln_filing_year', 'techn_field_nr', 'person_name']].drop_duplicates()
#     curr_app_year = current_app.appln_filing_year.unique()
#     curr_app_fields = current_app.techn_field_nr.unique()
    
    for row in current_app.values:
        curr_app_year, tech_filed, person_name = row
        if tech_filed in fields_with_its_greater_or_equal1and1:
            dict_of_leaders_per_tech_fileds[tech_filed][curr_app_year][person_name] += 1

# %%
df_leaders_per_tech_fileds = pd.DataFrame([])
flatten_of_leaders_per_tech_fileds = []
for key, val in dict_of_leaders_per_tech_fileds.items():
    cur_field = pd.DataFrame(val).replace(np.nan, 0)
    cur_field = cur_field.reindex(columns=[2014, 2015, 2016, 2017])
    cur_field = cur_field.assign(summa2014to16 = lambda x:x[2014]+x[2015]+x[2016])
    cur_field.columns = cur_field.columns.tolist()[0:-1] + ['2014-16']
    cur_field = cur_field[cur_field['2014-16'] >= 5]
    cur_field['tech_field'] = key
    cur_field.head()
    df_leaders_per_tech_fileds = pd.concat([df_leaders_per_tech_fileds, cur_field])

# %%
df_leaders_per_tech_fileds = df_leaders_per_tech_fileds.sort_values(['tech_field', '2014-16'], ascending=[True, False])
df_leaders_per_tech_fileds
# Out:
#                                                   2014   2015   2016   2017  \
# Cree, Inc.                                       131.0   73.0   43.0   50.0
# CREE, INC.                                        31.0    3.0   11.0    4.0
# Causam Energy, Inc.                               20.0   10.0    6.0   17.0
# The University of North Carolina at Chapel Hill    3.0    6.0    8.0    6.0
# ABB Inc.                                           2.0    2.0    4.0    1.0
# North Carolina State University                    5.0    0.0    2.0    4.0
# Valencell, Inc.                                    5.0    2.0    0.0    0.0
# Duke University                                    2.0    2.0    1.0    1.0
# Protochips, Inc.                                   3.0    1.0    1.0    0.0
# Red Hat, Inc.                                     66.0   52.0   78.0   49.0
# OPEN INVENTION NETWORK LLC                        23.0   24.0   50.0   35.0
# Bandwidth.Com, Inc.                               23.0   23.0   12.0    1.0
# SAS Institute Inc.                                11.0   18.0    9.0   11.0
# Open Invention Network, LLC                       12.0   20.0    0.0    2.0
# Causam Energy, Inc.                                9.0    6.0    3.0   12.0
# K4CONNECT INC.                                     0.0    0.0   10.0    2.0
# Qurio Holdings, Inc.                               8.0    2.0    0.0    0.0
# Odyssey Wireless, Inc.                             6.0    3.0    0.0    0.0
# Scenera Mobile Technologies, LLC                   4.0    1.0    3.0    1.0
# ABB Inc.                                           5.0    0.0    2.0    0.0
# Cree, Inc.                                         1.0    2.0    3.0    1.0
# Sitting Man, LLC                                   2.0    4.0    0.0    8.0
# The University of North Carolina at Chapel Hill    3.0    0.0    3.0    0.0
# North Carolina State University                    2.0    1.0    2.0    1.0
# Red Hat, Inc.                                    136.0  118.0  133.0  100.0
# OPEN INVENTION NETWORK LLC                        39.0   55.0   70.0   43.0
# SAS Institute Inc.                                52.0   56.0   42.0   52.0
# Open Invention Network, LLC                       18.0   16.0    2.0    2.0
# Duke University                                   11.0    6.0   12.0    9.0
# The University of North Carolina at Chapel Hill   11.0    9.0    7.0    3.0
# ...                                                ...    ...    ...    ...
# The University of North Carolina at Chapel Hill   37.0   37.0   33.0   22.0
# North Carolina State University                    9.0   11.0   12.0    3.0
# DUKE UNIVERSITY                                    2.0    1.0   19.0    0.0
# Parion Sciences, Inc.                              5.0    5.0    8.0   10.0
# Sprout Pharmaceuticals, Inc.                       9.0    7.0    1.0    0.0
# Viamet Pharmaceuticals, Inc.                       5.0   10.0    2.0    0.0
# BioDelivery Sciences International, Inc.           2.0    5.0    8.0    8.0
# THE UNIVERSITY OF NORTH CAROLINA AT CHAPEL HILL    2.0    2.0   11.0    0.0
# Cardioxyl Pharmaceuticals, Inc.                    4.0    6.0    3.0    2.0
# POZEN Inc.                                         3.0    5.0    5.0    0.0
# Argos Therapeutics, Inc.                           3.0    5.0    3.0    0.0
# G1 Therapeutics, Inc.                              7.0    2.0    1.0    0.0
# The University Of North Carolina At Chapel Hill    8.0    0.0    2.0    0.0
# University of North Carolina at Chapel Hill        6.0    0.0    4.0    0.0
# Chimerix, Inc.                                     3.0    2.0    4.0    3.0
# Precision Biosciences, Inc.                        0.0    2.0    7.0    2.0
# BioCryst Pharmaceuticals, Inc.                     4.0    1.0    3.0    2.0
# CEMPRA PHARMACEUTICALS, INC.                       3.0    4.0    1.0    1.0
# SALIX PHARMACEUTICALS, LTD                         3.0    5.0    0.0    0.0
# Salix Pharmaceuticals, Inc.                        4.0    2.0    1.0    1.0
# Scioderm, Inc.                                     4.0    2.0    1.0    0.0
# Cempra Pharmaceuticals, Inc.                       2.0    2.0    2.0    0.0
# Novan, Inc.                                        4.0    2.0    0.0    0.0
# PARION SCIENCES, INC.                              1.0    2.0    2.0    0.0
# Duke University                                    7.0   12.0    3.0    4.0
# North Carolina State University                    3.0    7.0   10.0    0.0
# The University of North Carolina at Chapel Hill    6.0    6.0    8.0    3.0
# bioMerieux, Inc.                                   1.0    5.0    0.0    6.0
# Bell and Howell, LLC                               0.0    3.0    2.0    0.0
# Pentair Water Pool and Spa, Inc.                   1.0    1.0    3.0    2.0
#
#                                                  2014-16  tech_field
# Cree, Inc.                                         247.0           1
# CREE, INC.                                          45.0           1
# Causam Energy, Inc.                                 36.0           1
# The University of North Carolina at Chapel Hill     17.0           1
# ABB Inc.                                             8.0           1
# North Carolina State University                      7.0           1
# Valencell, Inc.                                      7.0           1
# Duke University                                      5.0           1
# Protochips, Inc.                                     5.0           1
# Red Hat, Inc.                                      196.0           4
# OPEN INVENTION NETWORK LLC                          97.0           4
# Bandwidth.Com, Inc.                                 58.0           4
# SAS Institute Inc.                                  38.0           4
# Open Invention Network, LLC                         32.0           4
# Causam Energy, Inc.                                 18.0           4
# K4CONNECT INC.                                      10.0           4
# Qurio Holdings, Inc.                                10.0           4
# Odyssey Wireless, Inc.                               9.0           4
# Scenera Mobile Technologies, LLC                     8.0           4
# ABB Inc.                                             7.0           4
# Cree, Inc.                                           6.0           4
# Sitting Man, LLC                                     6.0           4
# The University of North Carolina at Chapel Hill      6.0           4
# North Carolina State University                      5.0           4
# Red Hat, Inc.                                      387.0           6
# OPEN INVENTION NETWORK LLC                         164.0           6
# SAS Institute Inc.                                 150.0           6
# Open Invention Network, LLC                         36.0           6
# Duke University                                     29.0           6
# The University of North Carolina at Chapel Hill     27.0           6
# ...                                                  ...         ...
# The University of North Carolina at Chapel Hill    107.0          16
# North Carolina State University                     32.0          16
# DUKE UNIVERSITY                                     22.0          16
# Parion Sciences, Inc.                               18.0          16
# Sprout Pharmaceuticals, Inc.                        17.0          16
# Viamet Pharmaceuticals, Inc.                        17.0          16
# BioDelivery Sciences International, Inc.            15.0          16
# THE UNIVERSITY OF NORTH CAROLINA AT CHAPEL HILL     15.0          16
# Cardioxyl Pharmaceuticals, Inc.                     13.0          16
# POZEN Inc.                                          13.0          16
# Argos Therapeutics, Inc.                            11.0          16
# G1 Therapeutics, Inc.                               10.0          16
# The University Of North Carolina At Chapel Hill     10.0          16
# University of North Carolina at Chapel Hill         10.0          16
# Chimerix, Inc.                                       9.0          16
# Precision Biosciences, Inc.                          9.0          16
# BioCryst Pharmaceuticals, Inc.                       8.0          16
# CEMPRA PHARMACEUTICALS, INC.                         8.0          16
# SALIX PHARMACEUTICALS, LTD                           8.0          16
# Salix Pharmaceuticals, Inc.                          7.0          16
# Scioderm, Inc.                                       7.0          16
# Cempra Pharmaceuticals, Inc.                         6.0          16
# Novan, Inc.                                          6.0          16
# PARION SCIENCES, INC.                                5.0          16
# Duke University                                     22.0          23
# North Carolina State University                     20.0          23
# The University of North Carolina at Chapel Hill     20.0          23
# bioMerieux, Inc.                                     6.0          23
# Bell and Howell, LLC                                 5.0          23
# Pentair Water Pool and Spa, Inc.                     5.0          23
#
# [130 rows x 6 columns]

# %%
df_leaders_per_tech_fileds.reset_index().to_excel(f'{CITY_NAME}\\{CITY_NAME}_заявители_по_областям.xlsx', index=False)
